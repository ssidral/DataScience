# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
"""plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True"""
fig, ax = plt.subplots()
df.year = np.linspace(0, 14, 73)
columns = ["year", "population",'growth']
df = pd.read_csv("population.csv", usecols=columns)
print("Contents in csv file:\n", df)
plt.plot( df.year,df.growth,marker=".")
plt.show()
# Out:
# Contents in csv file:
#      year    population  growth
# 0   2022  1.406632e+09    0.95
# 1   2021  1.393409e+09    0.97
# 2   2020  1.380004e+09    0.99
# 3   2019  1.366418e+09    1.02
# 4   2018  1.352642e+09    1.04
# ..   ...           ...     ...
# 68  1954  4.025786e+08    1.78
# 69  1953  3.955444e+08    1.73
# 70  1952  3.887991e+08    1.68
# 71  1951  3.823769e+08    1.61
# 72  1950  3.763252e+08    0.00
#
# [73 rows x 3 columns]
